# %% [markdown]
# # This notebook will serve as a way to implement character generation LSTM and other implementation

# %%
import numpy as np
import pandas as pd
import torch
import pickle
from Functions_generation import generate_a_song_structure, sample_with_temp_topk, CharLSTM

# %%
with open(r"..\Corpus\Encoding_RNN_LSTM\Char_level\encoding_map.pkl", "rb") as f:
    mapping = pickle.load(f)

int2char = {i: ch for ch, i in mapping.items()}
nb_char = len(int2char)

# %%
matrix = pd.read_csv(r"..\Markov\transition_matrix.csv")

states = np.array(matrix.iloc[6])
prob_transi = np.array(matrix.iloc[0:6])

# %%
embedding_dim = 64
hidden_size = 384
vocab_size = len(mapping)

model = CharLSTM(vocab_size, embedding_dim, hidden_size, num_layers=2)

# %% [markdown]
# # Teacher forcing = 1 during training

# %%
ckpt = torch.load("..\Models\LSTM_model_full_forced.pt", map_location="cpu")
model.load_state_dict(ckpt["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# I will give the same structure for RNN and LSTM to compare

# %%
struct = generate_a_song_structure(prob_transi.astype(float),states)

#struct = ['<BEGINNING>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<END>']
struct = ['α', 'γ', 'ε', 'γ', 'ε', 'θ']

encoded = torch.tensor([mapping[c] for c in struct[1]], dtype=torch.long).unsqueeze(0)
# Out:
# ['<BEGINNING>', '<COUPLET>', '<PONT>', '<COUPLET>', '<PONT>', '<COUPLET>', '<REFRAIN>', '<END>']

# %% [markdown]
# Forbidden to generate

# %%
forbidden_generation = [i for i in range(64,72)]
[int2char[i] for i in forbidden_generation]
# Out:
# ['α', 'β', 'γ', 'ε', 'ζ', 'η', 'θ', '€']

# %%
decod_structure = {"β" : "<INTRO>",
                   "γ" : "<COUPLET>",
                   "ε" : "<REFRAIN>",
                   "ζ" : "<PONT>",
                   "η" : "<OUTRO>",
                   "θ" : "<END>"}

# %%
context_gen = "voila pourquoi"
context_encode = [mapping[i] for i in context_gen]
context_size = len(context_encode)

hid = model.init_hidden(batch_size=1, device="cpu")

for i in range(len(struct) - 2):

    print()
    print(decod_structure[struct[i+1]])

    if i == 0 : 
        context_encode.insert(0,mapping[struct[i+1]])
        context_encode.insert(1,mapping["\n"])
        encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)

        print("".join([int2char[i] for i in context_encode[1:]]), end="")

        out, hid = model(encoded, hid)
        next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    else : 
        #next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).unsqueeze(0)
        next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).view(1,1)

    last_input = 0
    first_input = True

    while last_input != 12:
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

            out[0, -1][forbidden_generation] = float("-inf")

        # 4. On échantillonne un token
            next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
            last_input = next_token.item()

        # 5. Conditions d’impression
            if first_input and last_input == 12:  # Si début et le modèle sort directement <END>
                last_input = 0
                continue

            elif first_input and last_input == 0:  # Si début et sortie = \n
                first_input = False
                forbidden_generation.extend([0])
                print(int2char[next_token.item()], end="")

            elif next_token.item() != 12:
                first_input = False
                print(int2char[next_token.item()], end="")

                if 0 in forbidden_generation:
                    forbidden_generation.pop(-1)

        # 6. Préparer la prochaine entrée
            next_input = next_token.view(1, 1)

print("\n", decod_structure[struct[-1]])
# Out:
# <COUPLET>
#
# voila pourquoi est contre le plus blanc, j'suis dans le toit du père dans l'contrôle
# j'veux pas faire du mic de ton courage arrivée
# c'est pour mes bandits et au grise, c'est nous
#
# <REFRAIN>
#
# le contrat part en sous d'la bouche
# c'est la bièche en couille à charlouser le sang
# j'ai des cents qu'on est des construits dans la teste
# l'amour est des tours de s'conseile de rester comme un coup d'amour
# j'ai perdu le biff et j'suis comme le comme de toi
# les plus grandes déprimes sont des sous d'la base
# tu veux pas durer de la rechange des textes
# demain j'reste dans l'combat d'arrache de mes jambes dans l'cou d'un bout d'mes p'tits mères
# j'me rêve d'aller pour le balade comme si le son mais j'te rappelle en avance et j'suis pas tout proté et mes potes s'en sont des chevoirs
# j'ai dû l'espoir, j'ai pas l'trou d'amour et l'amis
# avant qu'tu connais le sous sans concert
# ceux qui vont tous les arrives d'humain pour les barrières
# c'est force de plus d'ennemi d'faire des mauvais soirs d'avance d'amour
# ouais j'ai jamais fait l'morceau
# l'amour d'avoir d'la forme et l'homme de paradis
#
# <COUPLET>
#
# j'ai la destinée d'autre poto, j'te l'aime exposer le marine de la rue
#
# <REFRAIN>
#
# c'est ma vie en face de l'avenir
# j'fais des potes du daron, j'suis pas au destin d'barrant d'appeler
# j'reste pas l'autre course de sous de la musique
# on t'espoir qu'j'suis la bouche de mes sous d'la cassette
# comme une peur l'ballet, j't'en perdre du sale des effonts qui s'passent
# de la coupe de couleur, nulle part de l'essence
# en fait des problèmes des sous d'la garde hollophanique
# j'suis comme un pote qui peut être le reste
# mais pas de nicker dans l'temps d'argent
# j'ai des fauxes gros, les fils en l'air de la casse
# tu peux pas t'faire l'envir d'une tatoute, c'est pas mon moton d'la salesse
# mais j'me dise à moins d'regarder le contre son de l'oseille
# en deux ans ou les yeux, j'fais les bouts d'survivre qu'on s'fight au moins qu'on fait des fois l'show
# des mois sur la feine, j'suis un peu d'premier dix ans qu'on s'fait des excuses
# et tu m'continues de parler de cirateaurs de sang
# mais j'suis pas si j'te comprends par la vie d'me tender sur les rimes et des cartes sont pas d'cents par toi de bien
# j'ai mon procrain a causé des concres de tous mes mots d'un tel-hô
# pour les miens qu'on prend tout c'qu'on riche à la gueule
# j'suis pas un port et ça s'est pas dégendu comme si je t'ai tout chez moi si tu veux pas t't'souvent
# comme l'adroncone
# j'suis dans l'parler d'comment on s'entendra pas d'avance
# j'suis comme toi tu t'prends rap et moi, j'connais pas les autres
# j'ai pas laissé le temps qu'j'ai pas trop d'échec en salaire de tout l'temps
# j'fais des distances de l'arriver ou des rêves
# des fois j'entends pas d'sous-titre
# j'suis comme une vie d'ma vie est une lite de solitude
# elle veut confiance à l'ancienne et mes potes perdent les rappeurs et tu dois tout le monde en primose
# on est d'la semaine de rimes sur les fermes de l'air
# on t'fait la prod sur l'time
# pas d'couplet, j'suis dans l'coeur ou la réconnecte des flics en or
#
#  <END>

# %% [markdown]
# # If no restriction on the generation part

# %%
context_gen = "malice"
context_encode = [mapping[i] for i in context_gen]

hid = model.init_hidden(batch_size=1, device="cpu")

encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)
print("".join([int2char[i] for i in context_encode]), end="")

out, hid = model(encoded, hid)
next_input = encoded[:, -1].unsqueeze(0) 

last_input = 0
first_input = True

while last_input != 70:
    with torch.no_grad():
        out, hid = model(next_input, hid) 

        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)

        if (last_input == 0) and (next_token != list(decod_structure.keys())):
            print(int2char[next_token.item()].upper(), end="")
        elif last_input != 70 : 
            print(int2char[next_token.item()], end="")

        last_input = next_token.item()
        next_input = next_token.view(1, 1)
# Out:
# maliceS
# /γ
# Ε
# J'ai le plus monte de la bouche et la vie c'est pas d'la femme
# J'suis à l'école dans le son d'la route avec une chose qui m'passe d'la mort
# J'ai déjà l'plafond d'la ligne qui s'achète dans des tracks, des mots d'air et j'ai pas d'marondule
# J'ai pu plein de sommets qu'on parle de merde
# Tout s'aime un peu d'oreille
# /ε
# Γ
# C'est pas la maille avant que l'époque de colon dans l'porc
# On parle de l'air
# Et j'conseille la confiance, tu veux pas rentrer en l'air
# J'me rends les miens j'ai l'sourire quand j'viens peut être un peu d'la street
# Le prémis d'appart on a pas d'temps le reste
# J'suis dans ma tête et le drame de trop en place
# J'vois le monde qu'il faut qu'les chansons sont bien d'la vie qui m'enterre
# On dit qu'j'en ai déjà pas d'vie d'expérieur
# On va pas qu'on fait des soirées
# J'relève des putes de princesse
# Pas d'se rendre en plein d'toutes les montres de la gueule, on est devenu vivre faut qu'tu vois qu'elle m'a peur de voir la vie comme un cash
# J'ai mis un complète de mes deux ans d'showton par l'amour, j'suis pas donné d'chez moi d'viennent
# /γ
# Ε
# Et des mots à l'aise et les paroles d'habité?
# J'suis pas d'ta chance en face d'un bitco et ma vie comme un coup d'école
# Mais j'suis le paradis qu'j'ai grandi toute prochaine
# /γ
# Ε
# Le projet au moins d'faire rapper des tasses de trait d'avoir des faites de toi
# Les gars se partent de mon corps avec les connes pour les mots, c'est l'temps de livre
# Ou des petits raisons, mes petits s'entressent
# En face du placard, j'les mets à tout c'qu'on veut donner m'appeler sans la base
# Et j'me dis qu'j'me regarde le mieux qui fait comme parler de la suite
# J'écoute c'que j'ai pas vu l'contrôle
# J'ai pas un mec de l'air mais pourquoi tu connais pas la street
# Tout c'que j'ai trop d'pièces de parton le coeur d'la base
# J'fais l'mal à la faire d'essence à changer d'sans
# J'préfère le cancer, j'ai pas l'coup d'autres
# J'suis un homme de la merde ou ma part de l'amour et j'l'ai pas d'personnel, j'traîne de la merde
# Et de faire les proches de rhum
# Tout l'monde qui m'achète pas les autres
# Si tu feras la merde, j'prends des portes que les potes s'appellent que d'la clique
# J'ressens le mal à faire de l'aventure, souvent j't'ai vu du bonheur
# C'est la musique de la tour dans mon ciel et le sel
# Les souvenirs de la vie, les potos sont des bandes money j'les fais pas de la tête, j'vais rendre sans connaître
# Tu sais qu'on se répète, j'ai le train d'fait, j'ai des listrouts
# Le salaire de moi, j'ai pas la maison comme le soir, pas d'la salitude, le rap est un peu par les miens ou qui m'appellent les sommes
# T'as mis un monde et vous m'arrête, j'ai pas d'temps qu'on a soigné pour le comme mais il est tellement
# J'ai pas pour du bon côté d'mes gars qui prisent de la ville
# En l'air dans les bancs de faire les postibles
# Tu connais pas ton pote comme le coeur et j'en ai plein de passe de pute
# Qui s'tente dans l'temps qu'on passe pas d'couille et le dos sur le temps de parler mais j'm'en bats des chiens
# Pour l'instant pour le coeur à moi les coups d'manquer la parmite
# T'as pas d'sous d'différent, on s'en fait la maille
# J'suis pas l'air sans faire du sac qu'il a semblant d'rouler d'un coup d'cendres
# J'en ai pas pas l'temps d'l'ingé, j'suis au studio et j'suis mec mais j'suis un salaire de voir un p tite de mon grand cassée d'haute d'avenir de l'or de merde
# Et puis tu t'as pas le temps d'un tarif pour toutes les baveurs de la plus heureux
# Peur du mal, c'est pas les poches
# C'est la vie c'est la sacret d'la première sourd et les putes
# J'ai pas la vie d'afrique dans la corde, j'les vends du bonheur d'cours
# J'ai l'sourire de la pluie et moi j'avais pas d'coup d'un state
# J'ai pas d'foutu d'la mort du maille, j'suis un peu au micro sur cette flice et ma p
# Mon coeur est les mains qui parent de l'amour comme la morale mais j'm'en bats le choix
# J'ai fait des molets qui sont pour les bras sac, j'ai du ventre de marcher de battre
# J'ai r'nous prises pour les miens pour la sainte
# Dans l'billet mais le billet d'la caisse d'oseille
# Ouais c'est les sous d'enfoiré, j'ai transformé la mort
# Comme un parleur de piste pour le désert sans la fête
# J'ai pas besoin d'un peu d'cash, des trucs qui m'appellent ou mais j'suis un comment d'la foutie
# La vie n'est pas la passion, j'ai des facteurs comme adame
# Fais pas l'point d'mes heures putes d'ange
# J'arrive de les traites et les hits rouges et les meilleurs les mots
# J'suis dans l'bras, j'fais des mains d'avoir une caisse de shit
# C'est une de la merde
# Les mots sont pris pour les mains
# J'en ai pas l'temps d'tout double, c'est ta petite balle dans l'choix
# J'suis dans l'artier qui s'en fout de la mertie
# Dans le monde plus de projets, j'me bats les remplis d'mon temps d'ceux qui t'arrachent de la maison de l'oseille
# Oui, j'm'en fous de la mienne et trois potes dans l'matin
# On est une pute de pause, mais ça sort le proche
# J'suis l'pécho dans le stress, mais c'est pas la vie d'enfoiré un descent
# T'as pas vu les plus forts toutes les passions qui s'terraient pas d'échanger
# J'ai pas l'sourire de l'époque de ma cabelle, yeah, yeah, yeah
# /γ
# Ε
# J'suis comme un patie de sucre sur la base
# J'me défais toutes les couplets dans les potes dans l'champeau d'or
# Si j'ai pas vraiment d'mettre mes parents comme un tour de pas d'début de l'amour dans l'plat
# Si j'ai l'échec et le destin s'enfoncent avec les coups d'poto
# J'suis dans le baison et tous les ventres sont sont chauds et l'appartence et j'ai plus l'sang fuck comme un cadeau
# C'est la vie d'me transir chaud, j'ai déjà la famille pour tout c'qu'il parle pas d'confiance
# J'suis dans l'cash dans la concusse comme la maison où j'ai pas capté la vie
# J'me suis toujours en fin de style de crève
# Et pour les bouteilles de mauvais problèmes, hey
# Oh merde, tu sais c'que j'suis dans l'sang
# J'ai pas d'philli, immense en salaire que j'fais qu'la maison est la mort
# Pour les sous de l'époque en concert
# J'entends pas l'monde et la pluie dans l'école
# Ils sont mécris d'autres rappeurs et les potes
# Tu voulais pas t'aimer voir les entrer des frères d'un monde sur la terre
# La rue c'est la base et les bras s'arrachent comme la solitaire
# Et les potes sont des parados comme un rime de moi
# On est pas la caisse et les larmes et l'tapiste
# /γ
# Ε
# Faut s'écrire le baril dans les putes de la maison, j'voulais pas s'te promettre
# Tout le monde est bleu, l'arconde est fort de tout comme un monde en haut d'me dire
# J'déconnecte les pieds, j'me suis devient pour tous les conseils
# Pas d'batterie, t'as jamais dis mon pilot, le collet de ma confusion
# J'ai pas d'grandi donc j'en ai branlé
# Pourtant j'pense qu'à l'époque quand j'ai pas l'temps en tieks
# J'suis comme un rap noir, j'suis dans l'matin qui m'a trouvé le temps d'humière à qui j'ai tout dit qu'on l'fait
# J'ai mis d'l'appel, j'rentre en rend en sous d'un film de la main
# J'ai pas d'phare et les succès de mes rêves de chiens
# Pour le game, d'l'est comme le soucie de sable et d'la cuise
# La vie n'a pas d'déchires d'une feuille de personne
# /γ
# Ε
# J'vois l'seul coup d'aller l'été d'la puissance comme les cours
# J'ai un coup d'la lune et d'un peu d'un peu d'tourner l'espoir c'est une phase ou les montes
# J'ai l'bat de consommes de perdre le malhier
# J'suis dans l'époque quand j'ai fait d'la mer
# Et j'suis dans l'studio, j'suis un peu de retourner
# J'ai pas d'pour me faire passer des couplets
# C'est les coups d'blanches pour une baille, elle est pas la vie
# Et j'veux pas d'être un terribe, j'peux pas voir les gens
# Comme un monde qui profite en concert, t'es pas de stress de faire les potes de mon coup
# J'ai la forme dans le style, donnez-moi la bruit de la nuit
# J'm'apprécie qu'handé d'une big et les plus frères
# J'veux mon cerveau au fond, j'ai plus d'bruit, j'pourrais pas rouger d'répiter
# J'ai rien de folie mais j'suis dans l'allemard mais c'est le feu
# J'vais pas pourrir l'enfer dans l'stress
# T'as pas d'lance, j'suis dans le bonheur de la jet-moi l'amour qui t'en sait
# Oui j'étais pas personne en plus fini s'envoler dans l'temps qu'elle s'enterre
# La vie est transformé, c'est l'enfer de toute la mort
# On est dur d'attendre leurs carrières
# Elle court du fond, j'remplis les papiers de joint
# J'ai tout dire qu'on va t'faire danser des limsa dans mon pote qui s'allume en place sans passer le jour
# J'ai le sourire dans la pour l'époque de me proposer, tu sais qu'j'ai une piste d'autre chance
# J'm'en veux pas d'tout c'qu'on m'a dit qu'on s'font des salopes
# J'ai pas d'rappelles qui trouvent toutes les plus prises
# Un peu d'ivresse de moi, j'ai la vie s'installe de paris, j'veux pas qu't'as l'mal à l'a posé d'aller pour mes deux, il t'a dit d'la place dans les pires de nos concerts
# Pour la maison de la merde avec le temps d'patater l'amour à ce que j'ai pas l'paraître
# Pour les miens perdu musique dans le point de la main
# J'ai pas d'sous mon parisier qui veut pas t'aimerait pas l'décoller
# Tu sais qu'j'ai pas d'mal dans la rue
# J'me dis qu'j'ai pas d'temps qui m'ont dis qu'j'étais d'la récité
# J'suis dans l'soleil que j'ai pas d'échangement
# Comme un jour on s'fait des humains qui parlent de la mer
# /ε
# Γ
# J'ai perdu les collègues pour des profs de ma chance de ma concurrence
# Il m'faut du monde qui m'appelle les textes
# C'est le bon ventre c'est tout c'qu'il fait l'amour est faite trop d'code, j'ai pas tout dire qu'y'a tous les potes
# En vrai qu'on m'a dit: comment je viens d'la même
# Des phases à moi, j'étais comme le plein d'costard
# J'suis dans l'peu pour les potos de la maison pour les larmes qui s'écoutent
# J'suis dans l'départ d'amour qu'on connaît pas la tête et rester les parkultes
# J'ai pas d'seille dans la chance dans un coups d'présent
# C'est pour le travail, moi, j'ai pas d'grand discrochet, on peut m'coucher des problèmes
# C'est pas la cause de ma pourtant ou qu'j'ai l'contrat
# On est partieux, t'es pas toujours au studio, faut qu'le sang
# J'suis trop d'oronies quand on avait rien à part du son
# J'me vois pas trop d'cons d'partis de la chapelle, pas d'reste
# Tous ces manques à fond du billet d'cash de l'élocate et des mariades d'alsconde, crois qu'les bonnes belgiques
# J'connais l'ancien de cauche dans l'coeur
# /γ
# Ε
# On fait que du coup d'argent pour les cartins, des trucs et tu m'as pas l'temps d'un sale et la vie, j'ai pas l'salame
# J'ai trop d'réveiller les larmes sur la vie t'es vu la fin du fond de descendre
# Et j'me suis juste des singes et les autres
# C'est la déficite, j'veux plus que j'fais des backs et les projets sont tout des moments de l'orage
# J'suis la concu comme un compteur de faire du coup d'amis
# /γ
# Ε
# Oh oh oh oh oh oh oh oh oh
# Oh oh oh oh oh oh oh ouh
# Ouh, oh
# Oh oh oh oh oh
# Oh oh oh oh oh oh oh
# /β
# Γ
# J'ai un tas d'manche et des mamans qui s'trompent de pile
# J'ai baisé l'espoir d'un peu mais j'suis dans la destine
# J'ai des faux sangles et les champs sur l'inspection et notre chance de ce nazi
# Quand j'ai un peu d'avance comme un excuse
# En espèce de parle de pas d'chienne
# Les projets sont toujours dans l'michon
# J'ai pas les plans comme un piston qui s'en sort d'mon plan
# /η
# Θ

# %% [markdown]
# # Teacher forcing < 1 toward the end of training

# %%
new_state_dict = {}
for k, v in ckpt["model_state_dict"].items():
    new_key = k.replace("_orig_mod.", "")  # supprime le préfixe "origin."
    new_state_dict[new_key] = v

# %%
#ckpt = torch.load("..\Models\LSTM_model_not_full_forced.pt", map_location="cpu")
#torch.compile(model)
model.load_state_dict(new_state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# Forbidden to generate

# %%
context_gen = "voila pourquoi"
context_encode = [mapping[i] for i in context_gen]
context_size = len(context_encode)

hid = model.init_hidden(batch_size=1, device="cpu")

for i in range(len(struct) - 2):

    print()
    print(decod_structure[struct[i+1]])

    if i == 0 : 
        context_encode.insert(0,mapping[struct[i+1]])
        context_encode.insert(1,mapping["\n"])
        encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)

        print("".join([int2char[i] for i in context_encode[1:]]), end="")

        out, hid = model(encoded, hid)
        next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    else : 
        #next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).unsqueeze(0)
        next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).view(1,1)

    last_input = 0
    first_input = True

    while last_input != 12:
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

            out[0, -1][forbidden_generation] = float("-inf")

        # 4. On échantillonne un token
            next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
            last_input = next_token.item()

        # 5. Conditions d’impression
            if first_input and last_input == 12:  # Si début et le modèle sort directement <END>
                last_input = 0
                continue

            elif first_input and last_input == 0:  # Si début et sortie = \n
                first_input = False
                forbidden_generation.extend([0])
                print(int2char[next_token.item()], end="")

            elif next_token.item() != 12:
                first_input = False
                print(int2char[next_token.item()], end="")

                if 0 in forbidden_generation:
                    forbidden_generation.pop(-1)

        # 6. Préparer la prochaine entrée
            next_input = next_token.view(1, 1)

print("\n", decod_structure[struct[-1]])
# Out:
# <COUPLET>
#
# voila pourquoi faire les potes dans les rimes mai
# s quand j'prends la drogue, pas d'taffer les baillets en moi comme la départ
# je me perds dans le plus allez pas de ton parceau de cash
# j'suis pas un film du bon cancesse, j'suis bien là-bas d'la merde
# c'est mon frère, j'vais pas t'faire mieux de la mort
# ouais j'vois qu'ce soir c'est la perte, de l'invente de la main
# j'préfère ce qu'on fait du coup, j'écris le change
# j'ai l'agot d'distance, on s'batraite avec le jeu
# combien d'paradis d'accoude en peine
# et j'connais la routine qui font des meilleurs pour baiser des mauvais de chantements d'action
# j'ai pas d'décider d'la défile et ta silence
# mais j'suis des frères dans le soleil de la folie
# pour les mains d'projets sur les albums sans aller dans mon temps qui dit qu'j'suis pas là
# j'suis pas d'la famille à l'autre autre bullet de la pagaille
# j'suis dans la porte de l'oreille pour le bété d'croire qu'on parle pas
# j'suis pas l'impression, j'suis dans l'histoire t'as trop d'temps, c'est pas le bon dieu
# j'suis dans l'sourire du bruit du magie, suis-tu baiser la maille
# j'suis récupérer le ballon, c'est un coup d'passer d'on coule
# j'ai pas d'choisi d'ma bite, j'ai pas l'seul de ma mère
# encore un année de main, j'ai des rêves par la confiance
# j'ai pas l'soleil de vivre, tu vois qu'pas d'mes problèmes d'habitudes
# j'suis dans l'coeur qui fait la démonnaire de la maille
# la vie est prend mais j'vais rester chaque pour la merde
# j'suis au flot d'la police et les partiers, j'ai appris à l'échec
# j'ai pas d'chier avec tous les pires de maisons pour tout l'temps d'la continue
# je suis pas la famille, ouais, ouais, ouais ouais
# tu t'es fais qu'les gens savent qu'ça m'dit
# concentre, les matins sont la concurrence
# j'ai plus d'ces années pour moi avoir de la merde
# faire le soleil comme un coeur et la peur de plus
# pas d'alcool, les poins des blessances de chanson d'avance
# tout l'monde est trop d'macis, tu peux faire sang affaire
# j't'en vois pas de contre ta le-gueu d'une mauvaise et j'ai d'la mer
# mais j'suis pas mon premier jour où c'est la femme
# j'suis pas de moi, j'm'en fais des lines
# mais j'fais pas les mecs qui parlent pas d'tes balances
# j'suis pas si t'es toujours dans l'style de cash, l'amour est parti d'art
# j'ai pas l'air de passé dans ma teille, c'est pas la mort de la cause de pute
# quand t'es comme des sous d'un peu d'sourire de skus
# non, nan, nan, nan, nan, nan, nan, nan nan
# j'fais pas l'temps à la banque de l'amour, j'suis pas présentielle
# si t'as déjà rien à toute la vie mais j'ai pas d'chance sur l'temps
# je parle pas d'crier comme j'suis dans l'temps pour les potes d'or dans les filles, on m'a dit: t'as pas le mal à faire de l'hiver
# j'suis pas en soirée d'la vie de l'école
#
# <REFRAIN>
#
# elle m'a déjà mes précisés de sous-titre
# si j'avais la merde de rime et j'suis dans les bails, que les étoiles dans la paix
# j'suis pas des chansons qui s'racontent les otrices, j'suis en plus de leurs filles, il va t'faire seul mes alien et l'époque du cash
# les souvenirs sont pas dans l'parler
# j'en ai tout là les jours d'autres, j'ai l'stud', le temps d'ma conseille,  j'ai l'cané d'la pièce dans l'estime
# on est des trucs qu'on a pas d'fantôme, j'suis dans l'coup
# j'suis sale la rue qui s'agit d'la rue
#
# <COUPLET>
#
# a la personne qui s'en bas des choses qui disent: coulisser toutes les petits contents
# et mes passents en affent d'ses frères qui peuvent que j'ai fait les blazes
# aujourd'hui j'suis pas rentré d'interneurs, pour avoir la démarre
# j'suis un peu d'mon coeur, j'ai des nouvelles
# c'est pas la famille d'ange, que j'ressemble d'air
# j'ai pas l'préférer c'est la mort de concert ou de l'homme de l'hôtel
# j'reste en peine de mes gars qui m'ont dit qu'j'inspire
# j'suis d'le feu de ton beat à la peine
# mais j'suis dans les paires de drôle de doute
# j'ai pas l'plain d'la soucis belle de la voix du compte de l'avant
# j'ai toujours des bitch dans les peines de l'argent d'casse de dix bergas
# j'ai le beau d'la maison, tu veux grandir comme le pire, donc j'veux pas s'est parler
#
# <REFRAIN>
#
# c'est chaud de l'autre pour mes problèmes
# j'ai pas d'permis pour les traces, pas sans le complet
# j'ai pas souffrir les poches de sales couilles qu'on fait des rêves
# et j'rappe mon coeur qui passe à l'amour et j'suis dans la concurrence
# le vrai la peur d'la porte de la maison
# on parle pas d'monde sur la nouvelle terne
# j'peux pas faire le défant dans le point de l'avant et j'suis dans l'crime
# et ça m'a revu des doutes, t'as capté la concurrence qu'on a pas d'meilleurs au milieu
# j'ai des partis et des gens qui m'dégalent, mes potes sont déjà les couilles
# j'vais t'me chercher des rappeurs de mon coeur
# j'suis dans l'game de l'époque de la maison
# j'suis le genre de bouteille d'espoir de la paix
# je sais pas qu'j'ai des soucis dans l'crack, le choix au trou de force à la cause
# les années sont sous la fin d'mes battailles
# c'est pas de la fin du sang seul qui s'barre en courant sur l'fond
# on fait des comptes de ce qui parle d'amour, j'en ai des mots dans l'compte et ma mère sait, oui, ouais
# personne ne soit pas l'temps d'être un peu de fou
# des pouvoirs avec les barrières comme des cours d'filer
# tout l'monde est part les jours de la marche de la merde
# elle vont mal à la plus fil de l'oreille, mais qu'est-ce qu'on s'en fait
# t'auras pas d'temps qu'il faut qu'j'veux pas t'aimer
# j'suis pas beaucoup d'putes de se cours d'la paire, j'ai des sous de faire le ciel
# en plus que je m'effache, c'est un million d'ma bite et la coupe d'amour
# j'ai peu de merde, plus de tasses en paris de rasson
# j'ai pas l'temps d'te javer le monde qui m'a mis ma tête
# le contrôle à faire de tout c'que les vrais rappeurs sont pas simples
# on arrache dans l'personnel
# j'suis pas dans l'temps d'mon coeur, j'ai un pote de sable, si j'ai pas l'mec des champs d'prods de la mort des putes
# j'ai pas l'monde et tu peux pas sûr qu'il y a un début d'casser le gang
# en vrai qu'j'avais pas vu c'qu'il fait bien qu'on s'est profilé d'la rue
# c'est pas un coup comme une musique de paradis de la vie
# si tu dois s'en bats les princes qui s'embrassent au ciel, je sais pas qu'il fait le champier longue de la vie d'mes p'tits pour prendre le goût d'l'argent
# j'veux pas t'faire des connards d'amour d'chez moi
# j'aime les autres et des fresses, on s'fait en soirée d'expliquer
# j'ai des filles dans l'passé d'se prendre le découpagne
# le prochain n'est pas bien d'autres mais qui m'appellent pas
# on n'a pas d'reston qu'j'ai créé d'la même tempête
# j'suis trop d'larmes comme une montre sans défiant
# j'ai pas d'tournois du coeur, j'ai pas d'lavé mais c'est comme ça qu'j'te casse des gars des baskets de rien
# et moi j'ai fait des faires de potes
# on veut juste comment tu l'prends pour eux
#
#  <END>

# %% [markdown]
# # If no restriction on the generation part

# %%
context_gen = "malice"
context_encode = [mapping[i] for i in context_gen]

hid = model.init_hidden(batch_size=1, device="cpu")

encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)
print("".join([int2char[i] for i in context_encode]), end="")

out, hid = model(encoded, hid)
next_input = encoded[:, -1].unsqueeze(0) 

last_input = 0
first_input = True

while last_input != 70:
    with torch.no_grad():
        out, hid = model(next_input, hid) 

        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)

        if (last_input == 0) and (next_token != list(decod_structure.keys())):
            print(int2char[next_token.item()].upper(), end="")
        elif last_input != 70 : 
            print(int2char[next_token.item()], end="")

        last_input = next_token.item()
        next_input = next_token.view(1, 1)
# Out:
# malice
# J'ai déconnenté dans les couches, les textes s'en fait des têtes de la sentière
# J'ai pas d'marre de ma bande, on a toujours la la base de l'ancienne
# J'suis pas là pour la mort et l'enfer, j'ai tout dit: j'suis pas d'mes parents de chaque meilleur
# J'ai des rappeurs me poussent, tu vis on est fraitique
# Avec les gosses qui peuvent qu'on s'engue la chance et le sang
# J'ai grandi dans l'coeur à belle, tu veux qu'j'm'en bats
# Qu'est-ce qu'on m'a dit: je n'me vois pas de trois textes j'réponds la concurrence
# J'ai dit qu'ça s'en plaît l'été honnête comme les couplets qui s'dégagnent
# Mais j'ai pas l'temps d'mes potes de sa fin
# J'viens d'chanter la poisse, les basons mais pas de maillans
# Et c'est le temps qui prend le connaissant, peux pas t'faire pas la famille
# A le nord mais j'ai des sols d'attendre
# J'suis dans le monde pour les gars qu'j'ai pas d'pensées d'artiste
# J'te la fais pas d'crise et ça m'voit plein d'mes rimes dans l'appriste
# J'ai plus d'eux comme les prières pour m'entendre d'la nuit qui voulait pas t'faire la doute, ma vie n'est pas très pour les cours et les problèmes, l'indétin ne peut rentrer dans l'manière
# On m'a parti d'puis la mort et son concert
# J'vais pas faire des choses qu'on sait que c'est pas l'amour que c'est la mort d'la rime d'arrête
# Tu m'as rentré au moins d'l'air de la foule
# Demande à la capitale, c'est pour le black dans les problèmes de shoot
# J'ai peur d'la main, j'ai peur de moi mais j'en ai des regrets
# /ε
# Θ
