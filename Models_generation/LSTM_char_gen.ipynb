# %% [markdown]
# # This notebook will serve as a way to implement character generation LSTM and other implementation

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch
import pickle

# %%
with open(r"..\Corpus\Encoding_RNN_LSTM\encoding_map.pkl", "rb") as f:
    mapping = pickle.load(f)

int2char = {i: ch for ch, i in mapping.items()}
nb_char = len(int2char)

# %%
matrix = pd.read_csv(r"..\Markov\transition_matrix.csv")

states = np.array(matrix.iloc[6])
prob_transi = np.array(matrix.iloc[0:6])

# %%
class CharLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, num_layers=1):
        super(CharLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(input_size = embedding_dim, 
                            hidden_size = hidden_size, 
                            num_layers = num_layers, 
                            batch_first=True, dropout = 0.15)
        self.drop = nn.Dropout(p=0.15)
        self.ln = nn.LayerNorm(hidden_size)
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, hidden):
        x = self.embedding(x)              # (batch, seq, hidden_size)
        x = self.drop(x)
        out, hidden = self.lstm(x, hidden)
        out = self.ln(out)
        out = self.drop(out)
        logits = self.fc(out)                  
        return logits, hidden

    def init_hidden(self, batch_size, device):
#        return torch.zeros(self.num_layers, batch_size, self.hidden_size)
        self.device = device
        h0 = torch.randn(self.num_layers, batch_size, self.hidden_size, device = device)
        c0 = torch.randn(self.num_layers, batch_size, self.hidden_size, device = device)
        return (h0,c0)

# %%
embedding_dim = 64
hidden_size = 236
vocab_size = len(mapping)

model = CharLSTM(vocab_size, embedding_dim, hidden_size, num_layers=3)   

ckpt = torch.load("..\Models\LSTM_model", map_location="cpu")
model.load_state_dict(ckpt["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
def sample_with_temp_topk(logits, temperature=1.0, top_k=50):
    # appliquer température
    logits = logits / temperature
    
    # garder seulement les top_k logits
    if top_k is not None:
        values, indices = torch.topk(logits, top_k)
        mask = torch.full_like(logits, float('-inf'))
        mask[indices] = logits[indices]
        logits = mask
    
    # convertir en proba
    probs = torch.softmax(logits, dim=-1)
    
    # tirage
    return torch.multinomial(probs, 1)

# %%
def generate_a_song_structure(matrix,states) :
    
    song_struct = [0]

    index = [i for i, p in enumerate(matrix[0]) if p>0]
    proba = [p for p in matrix[0] if p > 0]

    cumsum = np.cumsum(proba)
    r = np.random.rand()

    idx = np.searchsorted(cumsum, r)
    selected_value = index[idx] 
    song_struct.append(selected_value)

    end = False

    while end == False :

        index = [i for i, p in enumerate(matrix[selected_value]) if p>0]
        proba = [p for p in matrix[selected_value] if p > 0]

        cumsum = np.cumsum(proba)
        r = np.random.rand()

        idx = np.searchsorted(cumsum, r)
        selected_value = index[idx]
        song_struct.append(selected_value)

        if selected_value == 6 :
            end = True

    print([states[i] for i in song_struct])
    return([states[i] for i in song_struct])

# %% [markdown]
# I will give the same structure for RNN and LSTM to compare

# %%
struct = generate_a_song_structure(prob_transi.astype(float),states)

struct = ['<BEGINNING>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<END>']

encoded = torch.tensor([mapping[c] for c in struct[1]], dtype=torch.long).unsqueeze(0)
# Out:
# ['<BEGINNING>', '<COUPLET>', '<REFRAIN>', '<END>']

# %%
hid = model.init_hidden(batch_size=1, device="cpu")

for i in range(len(struct)-2) :

    print()
    print(struct[i+1])
    encoded = torch.tensor([mapping[c] for c in struct[i+1]], dtype=torch.long).unsqueeze(0)

    # prime the model with your encoded context
    out, hid = model(encoded, hid)

    # take the last token of the context
    next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    last_input = 0
    first_input = True

    while last_input != 79 :
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

    # sample from logits
        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
        last_input = next_token.item()

    # print char
        if first_input and last_input == 79 :
            last_input = 0
            continue

        if next_token.item() != 79 :
            first_input = False
            print(int2char[next_token.item()], end="")


    # prepare next input (still (1, 1))
        next_input = next_token.view(1, 1)

print("\n",struct[-1])
# Out:
# <COUPLET>
#
# J'ai bientôt j'rappelle à la tête de la saison
# Comme la carrosse sans planche de la puissance de Jobasse
# Car le parce qu'il écoute le bon est appris de l'argent
# Le sang de l'ans d'internier plus de combat de l'esport
# Ce que j'ai la rue le contrôle qui se plaie de personnes de toutes les barbes
# L'esprit qui n'a la raison d'un barreau de la picane
#
# <REFRAIN>
#
# C'est la mort du rap pour qu'on se reste de ma pute
# Mais les socs de l'arme de l'autre jeune faiteau grand
# Le retrouve de son enfant de l'amour sur la perdre de la coule du Havre
# Avec les gals de mon père en prendre de Sixi
# Mais je pourrais rappeller un papa comme un armé
# Au grand Maria et le poigt d'un arient de se passer ma street
# J'ai pas de ford à la seule de la raison du rap et le portur
# J'ai pas d'chanceur de partis par la partie de l'arme
# Le soirieur fait de l'autre justicite
# C'est la main d'Pure contentait de la traitre de l'argent de la double
# J'ai pas du peuple qui faut pas de tale de force
# J'ai mis l'air de la poule comme ce nous appelle le sous-ce de mon entre les projots de corps
# Comme Sabab et Pour l'argent par les portes de la lumière de mon point de la Merce
# Mais j'ai des oreilles d'ainsons de mon pote vivrait la première tout l'intell
# Je veux l'encelle qu'ils ont plus de chair
# Maintenant, le prénom du Homme
# De mon porte de la mort n'a pas d'amis comme les années de la provolite
# J'représense la planète du paradis de la mort
# Et me mattance de pousse dans le barbeau de rap
# J'ai parti invilé de compter la fin de nous
# Le banlieue de ceux qui ne s'en sortent de ma naître
# C'est la plume par les promès de temps que l'argent de la raison
# Elle vient l'fond de la vie de mon pour de tout
# Ils préfèrent pas de cœur qui part de la famille du parabon
# J'ai l'saille du gage dans le bésoir de l'argent
# Mais pour le préfond dans les barreaux de rappeur du rap chair
# Le changer par le mord du Port de ma marche
# Combe de l'Arabian Paris Panthère du cours
# Avec le course de la poission de carteors
# J'ai fait la course du point de nos guerres de la drape
# Le marque de la cassée, j'arrive sa plus pour faire le son
# C'est la puissance de la fin de la part de moi
# J'apparent les coups de l'ans envie de la couler
# Avec les poules de fois que je rends la street du truc
# Mais la paissin du Havre, une bouche de la souri
# Par le cadard car les maniances de la menté de la plane de la France
# Mais j'me trouve au rappeur de mon arme
# J'mets pas toujours sur le tort du besoin d'est-ce que j'étais d'la chanson dans la puissance
# Ou la caille avec les sactions contre les enfants de la carte de pression
#
# <COUPLET>
#
# Il parle de la pitat de toute sa contraire
# Car les gancs d'en cours qui s'ra pas de partie
# J'ai avais pas les mussons ont des cours du pression de manière
# Les couplets de l'arabe de la fille de la parole
# J'suis des potes qui veulent de la fort du rap qu'un artiste de la complicition
# Entre les conseils de pas sont des conseils de l'abge
# N'entends les portes de la pire du Dora Panthore et un monde
# La merbaille de la maison des gares en font
# J'ai la bandieue plus que les meufs de leurs portes de la première mais ton compte les potes, ce sont des corps de son de la mission d'un signon
# Comprends le poir de la peau de mon coup de bandel de la racie
# Mais pas c'est la coupe de l'amour du Havre
# Les femmes du rap français matin l'arricaliste
# Ces paroles de la partisse de mon gardit sur le coup
# On a pas d'ses couplets de ma barbe de la Barbe
# L'argent de l'argent et le croyant
# En parle de mon roseur sur la sous comme un anding de la seule coupe
# Mais j'ai pas de ma ponse
#
# <REFRAIN>
#
# Aucun daron de plaisaires de la partie de la feu
# J'ai pas de réconnaires comme un ari comme Agrenois
# Tu parles de la pour très bien que le dée bance de la puissance du Port du Havre
# J'ai fait bien plus de son de la musique du corusseur
# J'ai les couplets de perfues par les propres conçus d'encre le conseil de l'appe
# La France au bon d'arrivers, des rimes à l'ampérien
# J'ai compris la pille de la cade et leur liberte
# J'ai pas de pouils d'or avant de sa suit, des armes de rose sur les connagnes
# Ce sont les couilles de partir comme si j'ai toujours au tart qui m'a confiance
# Le faire de la comme un lalisse comme un frère de l'amour de sang
# Je sais qu'c'est la musique de la noire de la tess
# C'est mon place du marque de l'argé dans les troisins
# Les rappeurs sont riches et les frères de tarolisée
# Le peu d'me mettre de l'autre qui ne prend en coupe de l'autre
# J'apprends les petites marionnets de croix de ma derrière de bouleveur
# C'est pour les cinandes sont des livres
# C'est pas dans les tafs de toutes plus vers les propres de la mort
# Le manque de nos propres entre vise en plus d'arrête
# Quand j'me sens de coupler de la black du bonde
# J'ai le retour d'un partage de l'imposteur, que la puissance du Port du Havre
# Les magiciens, c'est ton sang de manière
# On s'préfère le monde en joue les chansons de futures dans le porte
# J'ai la même foi de mon voile de l'amour du Havre
# Le pouce est l'arrière de la rantaine en agiciel
#
#  <END>
