# %% [markdown]
# # This notebook will serve as a way to implement character generation LSTM and other implementation

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import pickle
from Functions_generation import generate_a_song_structure, sample_with_temp_topk, CharLSTM

# %%
with open(r"..\Corpus\Encoding_RNN_LSTM\encoding_map.pkl", "rb") as f:
    mapping = pickle.load(f)

int2char = {i: ch for ch, i in mapping.items()}
nb_char = len(int2char)

# %%
matrix = pd.read_csv(r"..\Markov\transition_matrix.csv")

states = np.array(matrix.iloc[6])
prob_transi = np.array(matrix.iloc[0:6])

# %%
embedding_dim = 64
hidden_size = 236
vocab_size = len(mapping)

model = CharLSTM(vocab_size, embedding_dim, hidden_size, num_layers=3)   

ckpt = torch.load("..\Models\LSTM_model.pt", map_location="cpu")
model.load_state_dict(ckpt["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# I will give the same structure for RNN and LSTM to compare

# %%
struct = generate_a_song_structure(prob_transi.astype(float),states)

struct = ['<BEGINNING>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<END>']

encoded = torch.tensor([mapping[c] for c in struct[1]], dtype=torch.long).unsqueeze(0)
# Out:
# ['<BEGINNING>', '<INTRO>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<END>']

# %%
hid = model.init_hidden(batch_size=1, device="cpu")

for i in range(len(struct)-2) :

    print()
    print(struct[i+1])
    encoded = torch.tensor([mapping[c] for c in struct[i+1]], dtype=torch.long).unsqueeze(0)

    # prime the model with your encoded context
    out, hid = model(encoded, hid)

    # take the last token of the context
    next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    last_input = 0
    first_input = True

    while last_input != 79 :
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

    # sample from logits
        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
        last_input = next_token.item()

    # print char
        if first_input and last_input == 79 :
            last_input = 0
            continue

        if next_token.item() != 79 :
            first_input = False
            print(int2char[next_token.item()], end="")


    # prepare next input (still (1, 1))
        next_input = next_token.view(1, 1)

print("\n",struct[-1])
# Out:
# <COUPLET>
#
# J'ai plus de la vie de tendre des cours de gagner
# Vous cent le meuble sur un courd et le marcher de la faute
# C'est pas le temps qui peut me déservier mes direaux
# J'ai l'air besoin de partir en monde de la mort
# Au loup de Paire et la fait dans la vie de coups de passage la guerre
# Si tu cartes les marches du fil de son porte de colactorise
# Avant que je suis bien n'est pas de diament
# J'ai mis du careman de la raconte de vos maisons
#
# <REFRAIN>
#
# Définition de ma village de la couleur
# Pour cette fois de l'immori de ma puissance du Parade de la Barbe
# J'ai appris le constrape du grand par le temps
# J'ai des policiers pour les bleus de passions
#
# <COUPLET>
#
# J'ai connu le cader d'on a bien le partin de ma ville
# Et j'ai vers le monde se part de part de la famille
# T'en avait pas de grands embales de la mort
# Et en solitale, c'est la pointe du barbuit de coups de putains
# J'ai pas d'années de mon basse du gueule de la rue
# Le carrache n'aut des couplets sont les frères d'un public
# J'ai comme des toutes de l'annité d'un double de pabisse
# Que des autres communcheurs toutes les contraires qui ne le connaisse pas de l'hard
# Mais le majet vient de ma race
# Mon père qui répète mon sourire de Cana
# J'ai l'effet de redonnait la plante de la puissance
# Faut pas rentrer l'arrière de prophe souvent le cartou de leurs mondes
# On fait les contraires de la première moi est un partis d'un boulon
# J'ai des morts avec les chiens qui se sortent les mailles
#
# <REFRAIN>
#
# Et le fautaise de Médine Protestie
# C'est qu'il coupe le contrôle de la rue, les choses qui m'restent de la carrière de la nuit
# Mais par la troisième seul noir aux armes de la maire sur le vieux des connaisseurs rours
# Parle que le fois que l'amour de provent les magains de bouteilles
# Le monde vise la coupe de la guerre, la plus frains du Havre
# J'ai parci le monde est passé dans mes potes de la Sute
# On va pas de malin d'un peuple de comme un coup de ma train
#
#  <END>
