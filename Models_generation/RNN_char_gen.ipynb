# %%
import numpy as np
import pandas as pd
import torch
import pickle
from Functions_generation import generate_a_song_structure, sample_with_temp_topk, CharRNN

# %%
with open(r"..\Corpus\Encoding_RNN_LSTM\Char_level\encoding_map.pkl", "rb") as f:
    mapping = pickle.load(f)

int2char = {i: ch for ch, i in mapping.items()}
nb_char = len(int2char)

# %%
matrix = pd.read_csv(r"..\Markov\transition_matrix.csv")

states = np.array(matrix.iloc[6])
prob_transi = np.array(matrix.iloc[0:6])

# %%
embedding_dim = 64
hidden_size = 512
vocab_size = len(mapping)

model = CharRNN(vocab_size, embedding_dim, hidden_size, num_layers=2)

# %% [markdown]
# # Teacher forcing = 1 during training

# %%
ckpt = torch.load("..\Models\RNN_model_full_teacher_forced.pt", map_location="cpu")

new_state_dict = {}
for k, v in ckpt["model_state_dict"].items():
    new_key = k.replace("_orig_mod.", "")  # supprime le préfixe "origin."
    new_state_dict[new_key] = v

# %%
model.load_state_dict(new_state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# I will give the same structure for RNN and LSTM to compare

# %%
struct = generate_a_song_structure(prob_transi.astype(float),states)

#struct = ['<BEGINNING>', '<COUPLET>', '<REFRAIN>', '<COUPLET>', '<REFRAIN>', '<END>']
struct = ['α', 'γ', 'ε', 'γ', 'ε', 'θ']

encoded = torch.tensor([mapping[c] for c in struct[1]], dtype=torch.long).unsqueeze(0)
# Out:
# ['<BEGINNING>', '<COUPLET>', '<COUPLET>', '<REFRAIN>', '<OUTRO>', '<END>']

# %% [markdown]
# Forbidden to generate

# %%
forbidden_generation = [i for i in range(64,72)]
[int2char[i] for i in forbidden_generation]
# Out:
# ['α', 'β', 'γ', 'ε', 'ζ', 'η', 'θ', '€']

# %%
decod_structure = {"β" : "<INTRO>",
                   "γ" : "<COUPLET>",
                   "ε" : "<REFRAIN>",
                   "ζ" : "<PONT>",
                   "η" : "<OUTRO>",
                   "θ" : "<END>"}

# %%
context_gen = "voila pourquoi"
context_encode = [mapping[i] for i in context_gen]
context_size = len(context_encode)

hid = model.init_hidden(batch_size=1)

for i in range(len(struct) - 2):

    print()
    print(decod_structure[struct[i+1]])

    if i == 0 : 
        context_encode.insert(0,mapping[struct[i+1]])
        context_encode.insert(1,mapping["\n"])
        encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)

        print("".join([int2char[i] for i in context_encode[1:]]), end="")

        out, hid = model(encoded, hid)
        next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    else : 
        #next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).unsqueeze(0)
        next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).view(1,1)

    last_input = 0
    first_input = True

    while last_input != 12:
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

            out[0, -1][forbidden_generation] = float("-inf")

        # 4. On échantillonne un token
            next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
            last_input = next_token.item()

        # 5. Conditions d’impression
            if first_input and last_input == 12:  # Si début et le modèle sort directement <END>
                last_input = 0
                continue

            elif first_input and last_input == 0:  # Si début et sortie = \n
                first_input = False
                forbidden_generation.extend([0])
                print(int2char[next_token.item()], end="")

            elif next_token.item() != 12:
                first_input = False
                print(int2char[next_token.item()], end="")

                if 0 in forbidden_generation:
                    forbidden_generation.pop(-1)

        # 6. Préparer la prochaine entrée
            next_input = next_token.view(1, 1)

print("\n", decod_structure[struct[-1]])
# Out:
# <COUPLET>
#
# voila pourquoij'suis pas d'la couvre
# les bras
# et moi j'ai pas d'habitude, tu m'verras plus en vrai et c'est réel, j'suis avec des mots d'la présence de porte de la merde
# alors j'ai fait du gardien sur le biff à ses potes sont pas d'armes
# j'ai pas d'quartier d'mes toxes
# si l'amitié dans la bouche te parle de ma perte de la bouche
# quand les mecs, j'ai plus d'amis au peu d'fric au moins qu'il faut qu'on fout d'l'arme de gars à la routine avec vos mots sont pas prêts à la poster le diable qui m'a ramené des malheurs d'un peu d'autre comme si j'étais le compte en assurer
# j'ai l'impression qu'on s'appelle dans la rue prémiser les portes de nous c'est l'barillet, j'ai des papiers
# on sait qu'on t'a dit qu'j'ai peur de l'amour et d'ma vie fait des rappeurs qui vont l'apprécier les mauvaises contrôlent au visage
# j'ai dit qu't'es pas devenir triste fois des choses qui restent de l'amour, j'suis là où j'ai l'air du bonheur qui s'désolé en espérant qu'elle est dehors de la série d'la merde
# mais j'aime pas un sky et les fois j'en ai pas la merde est longue est comme un frère et du perdu
# t'es pas prêt à tout est plus de la semaine de ma vie, au final, c'est pour les temps qu'on n'a pas d'sourire et d'la pluie de stress
# j'suis dans un peu d'faux sont les mecs de la maison
# tu n'as dit que j'en emmerde des potes
# j'suis dans la salle sans douter
# mais t'es le son d'une part de la maille
# tous les coups de putes
# de la soupe de ma vie d'la rage
#
# <REFRAIN>
#
# j'peux pas faire pour que j'ai pas d'amour en gros fils de pute est fou, je suis prêt à faire des trucs qui tirent et qui mangent des problèmes et leurs filles dans les trois rondes donnent des bonnets d'seule de tout ce que j'ai des bouches
# pas de bouffe à sauver les projets d'immense
# faut qu'on s'passe dans le soleil est bonne rouleuse d'or ici on a des mains d'sable de mon passé d'la peur de changer d'la sourire pour les enfants d'mon rap est des lignes
# les parents qui s'en rendent là où tu croyais qu'j'ai pas d'bails de la pluie du sourire
# on n'a pas de bonne boule de la drogue est mes gars c'est le page de vie d'ma mère c'est pas la fête sur mon prochain fils de daman s'était des conseils de la bouche de la vie d'boucle, pour l'instant j'ai des mouvements
# c'est quoi la famille mais j'ai la famille
# on fait des sous du feu de point est vide j'ai toujours pas d'mamen
# j'ai fait un regard du point d'cents-stat le reste pour moi c'est la vie
# mais quand j'ai rien à faire mal au micro comme un sac de mon coeur est à nos parents de la santé
# si tu parles de crock, j'ai du file, j'ai l'son de mon stylo et ma mère c'est pas la seule de couplet comme un converte, au taff et j'ai pas l'monde, j'fais des gros feuilles
# tu crois qu'tu peux faire du poing d'vie
# et moi, j'ai des parents sont pas bien comme si la sortie d'mes traits qui pensent qu'c'est de la base est sur la vie d'un compte pas d'douleur et de la merde d'action
#
# <COUPLET>
#
# j'ai l'seum dans l'futur de ramener ton rap est fait de la casse mais j'me repose des parents le jour à l'aise, c'est pas le jour où j'fais pour le point de pour qu'une seule de ma mère, j'ai des choses qui font d'la fumée, j'peux pas t'voir le tour d'la guerre à la preuve et le dos quand j'ai pas l'temps d'tous les fois qu'on l'passe pas aux placements d'putes et reufs et des petites seules marchent comme un coup
# eskondi pour les plaies
# c'est pas d'la force d'avoir des chances d'la banque est d'la terre, on s'envole à la boule de la perte de l'avenir
# j'les fais le tour de la base et la destinée
# et j'me déprome en maladie et les cartons que j'ai voulu m'ressemble dans la plupart de la carte pas d'contre des rimes, j'suis comme des deux
# j'vois la vie d'un jour, c'est pour un cles mots
# et tout c'que j'vais découpe des sons à cause de la rue comme le coup de faire le monde, j'ai la prod et puis j'ai des sales villes j'peux changer la pluie de la balle, j'ai mon problème et la musique dans les deux ont le marche avec des oreilles comme les marginaux comme le coup d'sourire et l'argent de la maille
# mes potes qu'on les coupe le prix d'ma porte de mon joint pour les parents disent que c'est la force de faire le fils
# entre le poids d'ma chance
# pour moi toucher la merde, que j'ai trouvé la peur en cours de ma colère comme un sud de l'espoir
# j'veux pas m'croire qu'j'essaye d'être des places
# mais j'ai perdu des sous
# tout niquer l'seum sur les paroles
#
# <REFRAIN>
#
# et j'ai peur de la peine pas c'que j'ai dit qu'il faut qu'j'ai plus d'traitres
# mais la maison
# tu peux pas tout m'connaissent qu'il est pas d'la fin d'mon mal que tu sais qu'on s'apprends à personne combien d'fumées sur l'coup d'main comme les frères qui fait qu'tu me parles de rap de la base, j'suis pas en place et appelle-moi les concerts d'part en couplet qui va pas s'désonner la suite, même si j'rentre sur la santé comme foot première fois qu'j'ai rendu savoir qu'il t'a dit qu'il faut qu'j'oublie pas qu'on a dit qu'c'est pas deux secondes et j'dis comme la daronne
# pour moi et l'enfer
# y a pas d'remplies pour mes sous, j'ai pas toujours le monde de mes paroles qu'on s'croit pas comme un pilon me parle pas d'la maison, mais les potes d'abord
# les problèmes font rien d'thunes de pute
# le son le collège
# j'ai pas d'doute de son nez d'la prochaine sourire, la flemme de parler d'cramer les sales pensées se mettent les miens d'la vie sans qu'il me fait un peu d'cent et d'la concu est tout dire qu'on parle de sa femme et les racontent
# pas l'temps qu'j'ai déjà dit qu'elle m'a dit
# j'ai l'air d'appart dans le mic avec des petits d'la main
# et j'suis pas fait d'mes pensées qui restent des larmes et j'veux qu'on m'a rien à faire
# et ça va t'faire la pompe au coup de soucis de la sauce de black de la prison
# le monde est déjà assez d'professionnels
# j'ai pas eu l'organique, non, j'suis dans l'parc de ma point de merde
# j'ai l'air dans le coeur de la console et le coup d'fumée pour le faire demain nous mettent des couplets frères qui parais mais pour les paradis d'la plage
# ce que j'ai la base, j'dis qu'je suis marcher d'la maison
# et j'fais des films de mon oeil veut l'soir
# les couilles sur l'temps de baiser des coups d'gens trop qu'elle fait des races, tout c'qu'ils m'cassent des sous de mes problèmes quand j'suis pas vite partout comme marweau la grand-mère et le stud', c'est le même danse, moi j'me dépasse les problèmes s'éclairent pas, j'prends le compte, tu parles d'amitié qui fait qu'des gens
# découvert
# j'suis dans l'mal aux années se ressemblent le monde qui m'a fait la capitale, mon coeur est au fond d'la soupelle pour la paix et les coups d'manasées par un plan par le loin de moi
#
#  <END>

# %% [markdown]
# # If no restriction on the generation part

# %%
context_gen = "malice"
context_encode = [mapping[i] for i in context_gen]

hid = model.init_hidden(batch_size=1)

encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)
print("".join([int2char[i] for i in context_encode]), end="")

out, hid = model(encoded, hid)
next_input = encoded[:, -1].unsqueeze(0) 

last_input = 0
first_input = True

while last_input != 70:
    with torch.no_grad():
        out, hid = model(next_input, hid) 

        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)

        if (last_input == 0) and (next_token != list(decod_structure.keys())):
            print(int2char[next_token.item()].upper(), end="")
        elif last_input != 70 : 
            print(int2char[next_token.item()], end="")

        last_input = next_token.item()
        next_input = next_token.view(1, 1)
# Out:
# malice
# J'ride à ces fautes de merde j'ai pas envie d'être là où j'suis rentrer tout le monde changer d'la police sans la fin d'mon pote c'est mieux qu'on découpe l'avenir qu'on s'embrase de la rue par la finesse, j'suis mentir les sons de l'argent de pas de garde des textes qu'on va tout c'que j'ai pas de partie d'l'amour est comme le centre de la peur
# Le coup d'vin du matin loin d'un coup d'malchance de l'ombre et des coups d'couilles, des points d'choses qui vont pas faire du sang de la route est pas comme si j'étais la soulever les mains au préfire pour les mains s'entretrouvent pas d'putes, je m'en rappelle qu'on t'en sorte de brisé d'mes binoles comme les putes de toute la mort j'ai des p'tites sentiments d'paname d'amis, on a envie d'me dire qu'les phases se calculent pas les portes et les mains comme si j'avais pas l'temps d'men chez moi, j'suis dans l'cercle
# J'suis bien tout près du barillet et les p'tits qui partent pas d'shit
# J'ai déjà d'jà mieux qu'c'est pour mes mauvais chances de moi le taff comme si j'étais chaud dans mon lit de la tour de cannabis, mais j'dis qu'j'suis dans l'cercle, les putes s'échappent de moi-même t'as pas l'temps d'trouver les coups d'taff dans la porte de rien à faire des fois pas la paix
# /γ
# Γ
# J'ai pas l'temps d'mettre une poucave
# Ils te disent qu'les plus d'parait la famille et puis si t'es que ces gens changent avec les couilles, j'ai mal au rap m'a dit qu'ça sent l'sur la pute c'est pas l'autre problèmes de l'idée
# On s'est pas besoin d'me rappeler la peur
# Et moi j'suis pas des plus de sous sous la mort pour sous instru mais tout l'monde t'en fout ma plume pour être tout c'que j'veux pas passer les mêmes poches de la nature d'appart par le grand coeur s'entendre à c'que j'me sens prêt comme les sales restos d'la tête de sa confiance qu'est-ce qu'on a des conneries, t'es pas même pas envie d'la cours de marmonnaire
# Que j'suis dans le bon temps de l'arrivée par les balles de poussière, j'ai trouvé la feuille et l'destin d'la vie
# J'ai un p'tit des enfants d'mes gars de temps qu'le cash se suivre et c'est le place mes paradis qui font des gars de la terre
# J'ai des connexions pour le monde part à la tour de parole mais moi, tu repenses qu'à l'aise
# J'ai pas attendre et qui s'baiser dans les parcours
# Dans la tête, mais les stups de moi et les médias, j'ai peur de plaire à tous les restes qui veulent pas faire le main
# J'en ai pas d'point d'faire à l'année pour les barrières
# J'ai l'enfer tout le monde sache qu'j'me connais pas l'alcool en mission de l'or
# Et moi j'suis dans le fric
# Les noms qu'on s'en a un peu d'séchant
# J'ai pas d'mentent
# Mais j'suis déjà mis d'la merde de vant
# /γ
# Ε
# C'est pas le premier compte qui m'a dit qu'on doit dire qu'on fait des gens qui braquent les parlent
# Avec ma vie
# J'vais pas faire semblant qu'j'connais la maison entre le fond d'la salle de balance les balles
# J'regarde les couplets de compte pour mon amour et des sous
# Personne c'est l'coup d'merde pas de merde de moi, mon coeur et qu'ils sont très bien pas pour mon amitié prochain avenir c'est le sable de mes gars sont pas tout dit qu'on peut t'manqué d'la rue d'ma mère fait des bails de rimes sont sous la merde, j'te parle pas d'temps d'l'habitude
# J'ai pas envie d'le faire du bénéfice se donne le soleil va t'appeler qu'j'ai pas d'couplet, t'as pas l'marcher toutes les coups
# Le reste, pour les gars d'enfants de ce soir c'est comme le premier cinq de deux fois j'suis l'monde de la la toi, on est pas dans les bails, j'ai des pourris d'la mort mais j'suis la santé d'habitude
# Mais j'ai pas mis la vie d'homme de la main
# J'ai déjà dit qu'on dit qu'j'ai trop changé d'la rue de rap de routine qui parle de chasse
# J'ai la facilise le vide
# Et quand j'ai plus d'pour l'instant je crois qu'j'ai mis aux miens de bon poisson prend les prénoms
# Et j'ai plus de mon coeur et dangereux que j'ai dit: vendre des plans d'construits de ma vie
# Les couplets de shit et faut qu'j'ai trop d'envies d'un pétard c'est ma cité de ma paire de battement de soit ta mère
# Mais on a fait le coeur
# /γ
# Ε
# Pour la base, c'est la paye de la prime d'appart pour moi, ouais, j'vais pas m'apprécier mon ancienne
# Et puis j'ai pas l'choix, merde me parle le bon prix d'la boule
# Recommencer les bonnes chansons d'super voilà où j'ai l'soleil est précis
# J'ai des peurs qu'on en fait le bonheur et la calme de ma console avec mon flow qui batte le basket à moins d'mes chansons d'autres qui passent avec des problèmes vont rentrer d'aujourd'hui, j'ai pas d'amour sans profiter d'faire un peu d'freestyle tout l'monde de la poisse avec des problèmes croisent dans la pluie de nous on s'tape les miens d'mes mots de salaire
# J'suis sur la sauce
# Mon clip de force de faire des gens qui connaissent des nuits qu'on s'passe
# Dans les gens qui croient qu'on dit qu'j'suis pas prêt à nous teste le faire
# /ε
# Γ
# J'suis un peu d'ma vie comme au dessus
# J'suis pas là j'suis sous la boule après la course
# J'ai vu les concerts d'ma faute de bouteille de stresser les paix, j'ai l'soutien d'putain d'plans
# J'suis dans un amour, c'est la mort et le fric et les plus d'la concurrence qu'j'ai des noirs qui pourraient pas faire que si j'suis pas là, ouais
# C'est la porte et les mains d'la main, j'suis pas personne n'est pas là, j'me dis que j'peux pas connaître mes années
# /γ
# Ε
# J'étais souvent pas les moments sont la part de moi de contre le monde comme des seuls pas comme le son comme un acteur de nos potos fermés d'un monde
# J'dois faire des restos d'attention est mortel
# J'suis toujours en désolé à ma poche
# J'ai des affaires belles petites bourgeois
# T'es pas pris du rap c'est pas un peu d'mes potes dans ma tête et pour s'connaitre des p'tits bougent et leurs minutes veulent des coups d'couilles
# Et qu'est-ce que j'ai pas l'seum et tout l'monde est moins d'faim de ma caisse d'l'amour qui se réveille de son fait pas d'pompes
# J'suis en paix qui s'en sortir des sous de ma console de style, j'ai tout le temps qu'on s'disait qu'j'ai capté les larmes au palais baiser des paradis, j'transforme de l'amour est pas là où on dit qu'tu m'as pas cru que j'ai pas d'p'tit temps que j'ai pas d'enfant du bunk mais j'viens des tracks
# J'ai des parents
# /γ
# Γ
# Ce que j'viens d'la vie
# On parle de ma vie d'un coup d'ssus d'mes doutes, mes trois parasis
# Tout l'temps d'une fille sous l'accepter l'temps en plus bouche avec les coups d'mois l'amour est un peu plus cliqué dans mon papier, le billet et parisienne de sky
# /γ
# Γ
# T'es pas devenu bardelone
# Pour les enfants du tas d'posters de la paix, j'suis un basket pour les presque soin d'la maison
# Tu peux pas t'en veux qu'j'me termine ma constation s'arrête ta mère, c'est pour mes couplets rappent de la chance
# J'suis pas de l'époque où le caraliste
# J'ai pas pas les bandits qu'on manque de la part de la paire
# J'ai pas d'travail
# Comme le pain, mais pas d'idée
# J'étais comme le monde d'autres coups d'chansons de la fumée c'est pour les couplets d'mon visage pas d'la force de complexe de bout d'spectacle, me rappelle pas qu'la tête
# J'ai plus d'couplet et tout me disent mon grand chance de la mort
# L'autre chemin et plus l'monde pour le rap, c'est pas si t'en as dit que t'as pas de mec de la vie de mon monde de pute de ma la matrice et l'coup d'sourire de la main par la magie dans le soleil de ma fille de faire les tapes dans les étoiles, des rappeurs j'ai des deux princes
# J'sais qu'le contrôle à l'année d'la santé, c'est pour la paix partout d'mes rêves et les fleurs de papa disparaître les plus de force de m'achète les larmes et les durs qu'en place de pute, les autres de son shit, le rap c'est la tristesse de la course, avec eux, c'est la maille les racistes j'ai d'la pour tes couilles de la chapelle, j'suis dans les soeurs de poisson de la maison c'est d'la main et l'porte
# Charbonne
# T'es fini d'pas d'croisières
# Les fils de pute dans le volume que t'es un peu d'mes rêves
# C'est la troisième coup
# /ε
# Γ
# J'suis pas prêt à la base
# Il fait ma vie pour les bourrés d'coupures de personnel
# Aujourd'hui, j'ai mon état
# J'suis pas l'adresse des textes
# J'ai pas d'alcool et le fait de l'amour
# J'suis pas dans l'réel dans le chala
# J'veux pas la reconnu comme le plus important d'la maille
# Un peu plus qui parait pas pour mes rendant d'ma mère crois pas que j'vais pas baiser les souvenirs d'un autre passion, j'ai la tête qui parle de l'époque où j'me dépasse des peurs sans merde
# Comme les meufs, j'ai pas d'fou à la maille
# Tout est pas inconnu cette fille de billets l'micro comme les couleurs mais j'ai des petits partent, c'est des fois j'ai mon temps d'tout c'qu'il fait qu'tout ce que j'ai pas d'place sur les mains pour les concerts pour prendre ta concurrence de michel au monde et les fois d'un combat la foudre et c'est pas l'futur passe et j'suis un jour le paradis
# Mais j'en ai pas d'or de la vie d'un son
# J'suis pas pas le chantier
# J'ai peur de la stap, j'ai la fin d'arrêter de la police
# Avec mon problème a besoin de tout l'monde comme les pièces de ma chaîne de rap sur les plus d'faibles
# Tu fais du chance la crise de sable dans les couilles et sa la place de billets la fraîche et les projets de la maison, j'ai plus d'année
# Les vrais font des prières et les og d'la mort comme moi de la mort
# J'suis là où j'veux pas rentrer
# Et les pensées mon coeur
# Et si tu parles de faire les frères m'attendre nos choses qu'c'est trop la victoire qui réponds rien de moi
# Dans l'patrick de chanter le joint de la nuit
# J'lui dis qu'j'ai la danse de base, j'me prépare la chaîne
# C'est pas le centre et l'amour est présent comme des instants de la mort, j'ai des choses qu'on est vieux me connaissent les mecs brûlent de toute la face comme un gros contrat mais j'prends les projets qui s'arrêtent
# J'ai pas les beuhs pour la coupe mieux qu'l'amour d'arrêter d'la drogue
# En soirée sans cent pas sur les miens
# J'ai toujours des bavers visions d'ma peau d'amour dans la famille
# J'ai accompagné, bourré
# Des crocs d'mon temps qu'on dis pas si j'ai fait tellement tout l'monde sans passer des parents s'demandent les politiques sont comme un tieks
# On est moins d'mes proches qui s'envolent
# J'suis franchement, j'ai des proches
# J'ai des crimes de la vie qui parle de l'amour pour un peu d'mes parents que j'ai fait les catroches
# Les flics de mes parents sont tout près d'la peine pour les prods toute ma came sans dire qu'on connait pas la la la pas moins te faire les bourgeois comme le monde de tout est plus des pompes de mon pote, la mif de la vie d'ma place de vanade par coeur en place a mon parcours
# Je connais l'film, j'connais pas d'pour trois gens qui sont pas d'autre comme se faire des doubles avec des paradis
# J'rappe pas comme les mains de mon détail, on est deux pour mettre le capuche, c'est pas tout c'que j'ai pas la vie qui s'passe des coups d'choses qu'on s'en veut pas croire qu'on parle de mon petit album des époques
# C'est que du matin j'ai pas les champs de faire des larmes de mon poto j'ai pris le bonheur est ailleurs, plus d'tournée ou tu me demandes l'décor
# Pour mes disques, j'vais t'en dépression
# J'ai pas d'mensonges sont faits dans l'peu d'sang
# J'ai l'coeur avant qu'ces ronds d'cinq contrôlent et posés dans le plafond, j'ai toujours pas l'temps d'si j'suis pas les fils de putes et j'ai pas de rap pour le bonheur qui a pas trop libre de la faute de la manière tout c'que j't'aime de provoquer les putes sur les meilleurs sont des poches vont le dire qu'on s'en sortir ma vie est plein d'or mais j'ai mal à chaque vie d'cent bitchs ou de la police de la poche
# Il est rien d'un travailleurs attendre de l'or avec mon propre croc
# Le plus beaucoup d'mande au dessus, j'veux pas rentrer d'habitude
# J'suis pas plus les coups d'concerts repassent d'un con d'mes nuits qui m'en foutent de travailler les barres et du dojo de l'apprendre des couloirs coupeurs dans le putain d'contraire de ma pression de mes billets d'mon bail on vient de la joie de la baise comme un propre constat de l'arrière de la tête d'attente, j'veux pas d'accord
# J'en ai pas d'train d'moi
# J'suis pas seul mais j'parle pas d'cours de nous, mais j'ai dit: son bout d'sourire dans la salle que le plus impossible que j'ai l'seum qui me regarde pour les meilleurs paracent des poches qui sont plus les sirènes de prod et les corps de putes sont tous nous on a pas d'crossche de passe mes potes sont morts
# Mais c'est toute la punch d'alcool , je fume des poèmes mais j'ai pas compris qu'j'ai la vie
# /ε
# Γ
# C'est pas l'monde est des choses d'ma vie, j'ai la course et tu sais qu'c'est tout seul comme les preuves d'avoir l'homme
# Plus d'sentiments
# J'vois des couplets d'mes potes m'faire des shots
# C'est pas la base et moi et puis j'ai pas l'monde de capitale
# Mais j'ai rien à foutre de voir ma vie d'mes neiges
# Et c'est le fils de blague et la main et la prod comme les shettos français qui parlent
# Ne le fais d'la vie, j'ai des textes et ton rap française
# Mais trop d'confortent sur le chanter l'enfer en bas de mon pote, le temps qu'on compte pas les papiers
# /γ
# Γ
# J'ai pas moins d'rimes et de la mort qui a des problèmes sont pas trop là qu'j'ai d'la plais d'la santé d'prix de la la la haute de rap sans t'dire que je me porte ma vie et les deux balles
# J'suis dans l'bar de loups
# J'ai vu le stress dans le cash et la tête et me découpe le coeur dans les mauvaises flammes
# La peine, mais c'est dit si j'ai conscient qu'j'suis tout c'qu'il m'faut le mic et les putes et des esprits d'prévide pas mes deux textes sont pas la peine
# /ε
# Γ
# J'ai des problèmes
# C'est dur de faire de la programme, mais j'ai vu l'doigt et le contrôle
# J'suis un bar de vide pas, j'te ressens des premières problèmes d'arrière du monde au bout de la monnaie
# La vie est mince des petites chansons
# J'vis des pailles
# J'suis pas chaud
# J'fais mes bouteilles
# /γ
# Ε
# J'me sens infoncer par la mort, tu veux qu'j'ai des autres
# J'ai pas fait qu'j'vais m'cacher les gens qui s'tendrent comme dans ma le-geu, j'essaie d'être une famille en grand grosses poches et j'me repense à nous c'est le seum, sans regard dans les miens font pour les mêmes sens mais j'ai peur d'la semaine, j'ai l'temps d'un passé de la gare, mais on navigue d'asphalte et son destin d'ma part du beau mal à m'mettre dans les bonnes cataras du seum de l'autre pour qu'le temps qu'j'suis dans l'coeur de contre nous, on a la tête dans la caisse, j'ai plus d'faux frères, des mots qui s'défaitent
# J'suis pas bien des pétasses
# J'me sens pas de stress, ils sont pas très des alcoolos qui s'parlent de son visage
# J'suis comme les problèmes au studio et puis j'ai pris les miens
# C'est ma vie d'mon coeur dans les flics près d'la force de vous m'connaître des couplets s'éteignent
# Moi j'viens du loup, j'reste des fois où j'ai peur de la carte et tu peux pas faire le coup d'faire des avenirs
# J'me relève tous les flics sur les mecs dans le monde comme la pulsion, mais t'as la race dans les plus facilement
# Si on connait pas quand j'ai dit qu'elle s'en bat la france par la crasse de la maison
# Prends mon oreille
# J'suis avec ma famille de ma passion est des histoires à la forme
# On parle d'accord d'autres de tout l'temps à la face au pire
# J'roule un pas ma la chatte, j'me suis changé de l'argent m'a connaître le boule à la main, j'ai pas trop l'meilleur de vivre de la poussière en face de moi
# Les potes m'a dit j'ai l'peu d'grandes fois qu'j'ai déjà d'la prose fin d'la routine a perdu des mirages de ta vie , on s'échappe de mes parents manquent pas l'prénom d'un compte de l'année
# Donc j'suis mort branche le bonheur comme la salle et des bails de fumées pour le mic', j'vais pas la sentir pour les trois des mains d'l'alcool et les propos ou d'ma porte de l'instant, j'suis deux, j'ai peur de la bouche, j'ai pas toutes les autres m'attendent pas comme le gars pas découvrir les posts au fond, c'est pas du bien sur l'appart
# Tout c'qu'il m'dit: tu m'as pas l'observe le bonheur qui reste le respect
# Des rimes sont pas douments sur les trains qui m'ont dit qu'j'ai tout dit qu'c'est pas fait comme moi qui définition et la famille de pas avoir les miens me disent qu'on les douillé, j'viens de la main d'rien d'amour et la troisième route en fait le coup d'taff quand j'étais comme le tout ce que j'ai fait la maison est pas de l'ombre d'ma peur du pull et le matin t'es comme le maire
# Personne qui passe un peu d'bois pour le studio
# J'suis un big repas d'belles sons et des parents savoirs sont un coup d'belge de la bouteille de plein d'ma vie de la plume, je suis pas menti dans la tête et les films d'autres
# On s'en fout d'la maison, j'fais qu'la santé
# /γ
# Ε
# J'essaie d'me faire tous les mains et se croisaient le ciel est là où il est sans pêche
# On connait pas la vie c'est la peur
# Tout ça ma famille
# J'ai un bout d'crasse
# J'ai trop d'organiques, j'suis dans le parcours d'amour, mais j'suis pas de pour les faux sont par temps d'la culture
# J'suis pas un mois d'grands tripes de leurs textes, courir dans l'taba et la personnel
# Le sang
# Les dix ans de mes potes d'un coup d'main des placements
# Les années comme les miens comme un autre mais j'suis dans l'seum, je fais pas d'ta maison, on s'dit qu'j'ai qu'un mot de chasser le camen, je suis pas l'heure de la crasse avec les blazes de merde
# Et toujours une constatiés et des textes qui s'réveillent et des fenêtres qui m'ont fait le bus d'contre les putes de toute la nuit a marre de tout le monde sait qu'on a dit qu'j'me dis qu'j'suis attiré par les barrières
# J'ai peur d'la maison, pas d'portes de faire savoir qu'j'suis comme le choix en casse-pipe de la maison, mais j'crois qu'on vient d'la banque et j'suis pas tombé d'ici, j'vois le temps à des musiques de la blanche
# J'ai fait des gros cous trop bandes de la base, c'est pas moi qui a toujours des marchent comme un truc d'un feu d'nos demises comme dans ton amour du bateau comme le même grand des coups de prod d'la balle de la fouger d'la pute
# Des chances de rien
# /γ
# Θ

# %% [markdown]
# # Teacher forcing < 1 toward the end of training

# %%
ckpt = torch.load("..\Models\RNN_model_not_full_forced.pt", map_location="cpu")
new_state_dict = {}
for k, v in ckpt["model_state_dict"].items():
    new_key = k.replace("_orig_mod.", "")  # supprime le préfixe "origin."
    new_state_dict[new_key] = v

# %%
#ckpt = torch.load("..\Models\LSTM_model_not_full_forced.pt", map_location="cpu")
#torch.compile(model)
model.load_state_dict(new_state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# Forbidden to generate

# %%
context_gen = "voila pourquoi"
context_encode = [mapping[i] for i in context_gen]
context_size = len(context_encode)

hid = model.init_hidden(batch_size=1)

for i in range(len(struct) - 2):

    print()
    print(decod_structure[struct[i+1]])

    if i == 0 : 
        context_encode.insert(0,mapping[struct[i+1]])
        context_encode.insert(1,mapping["\n"])
        encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)

        print("".join([int2char[i] for i in context_encode[1:]]), end="")

        out, hid = model(encoded, hid)
        next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    else : 
        #next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).unsqueeze(0)
        next_input = torch.tensor(mapping[struct[i+1]],dtype=torch.long).view(1,1)

    last_input = 0
    first_input = True

    while last_input != 12:
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

            out[0, -1][forbidden_generation] = float("-inf")

        # 4. On échantillonne un token
            next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
            last_input = next_token.item()

        # 5. Conditions d’impression
            if first_input and last_input == 12:  # Si début et le modèle sort directement <END>
                last_input = 0
                continue

            elif first_input and last_input == 0:  # Si début et sortie = \n
                first_input = False
                forbidden_generation.extend([0])
                print(int2char[next_token.item()], end="")

            elif next_token.item() != 12:
                first_input = False
                print(int2char[next_token.item()], end="")

                if 0 in forbidden_generation:
                    forbidden_generation.pop(-1)

        # 6. Préparer la prochaine entrée
            next_input = next_token.view(1, 1)

print("\n", decod_structure[struct[-1]])
# Out:
# <COUPLET>
#
# voila pourquoitu sais pas les states de toutes les deux pas mes deux bougies sont tout mal de souvenir  lls me pas de paper  plus de tense s'il fait les nouvelles font peur, c'est pas les coursss pour le  fleurs et les blagues de son doigts de ces tours et j'fais pas les mains sont toutes les montres, sage dans les plus de bars   deux points de ta merde
# j'me dis qu'j'ai pas d'regard de mon pote dans la maille
#
# <REFRAIN>
#
# j'suis dans la mort de mes plattes les mots ee monde de mes regrets sont faut mais j'me rappelle toutes les bougies de la maison est un son de porsse, vers les deux sont les problèmes sont les bougies moiss de mon coeur de mon contraire, j'ai tout peur de les scheets
# le  coups de sous  mama les yeux mais j'écoute pas de  plus forts de la force de saille , tu m'les vois pas les plus coups d'prrents de courte sont des polites de tout les plus trop de mes soumis comme un petit décider
# c'est moi qui devient un faux comme l'école
# j'suis un  femme d'aart mon rap, arrose plus qu'on aeut trop d'plus sous fait rester des télépressions
# j'ai des ailleurs, parle de faire une vibe
# dans les monterres  on t'a dit  pas d'faire ses papiers et c'est pas une fleur de tous les sommes de ta merde
# et pour tout c'que j'ai trop nous demain tu veux des coups d'mes petits qu'on suit un plan  j'vais t'amité les loges de comme mon parfois j'ai pas les plus de frigo dans les baaass   trois fois tu veux pas qu'j'pourrais pas t'rappelle-moi c'que j'me trouve les coups de gros cools d'aa gueule
# si c'est pas une fin d'nne chaud de tout les meees mon ooeur s'il m'faut l'été, j'ai tout comme le mien s'fait pas les basses de tous les troubles, on fait le balles de raconte, j'suis pas un  fiis que j'plaît
# j'te dis pas qu'il me fait pas le monde pour mes tours
# les voitures
# les pour la plume d'plus de mon artiste, on parle de la chaussine c'est quoi les bourbes
# il t'a dit qu'j'aais les problèmes, j'vais aas besoin d'une vibe, j'ai pas les autres et son   comme une vibe, on peut faire sans légendaire, les plus insouffrer  comme les blagues de souvenir dans les belges
#
# <COUPLET>
#
# y a des parents mais j'ai peur, y'a uuelques plus belles couplets de coups d'black
# balle  les petites mais pour les banques de mous  comme un comme un  terre et j'les rappelle pas d'le  voir ees deux fois j'suis pas viee d'artiste, couplet et nique les bails de la bouche
# c'est pas l'choix de la plume de changeance toute la nuit pas d'chose dans les cours de mes paofesses de mon pote et j'ai pas un  blague, t'as pas de plus de la vie, j'mets un petit flow dans ma tête comme double coup d'temps d'les son dans le  fleurs  mais on sst chiante, j'peux pas t'faire de la main peut brûler des tours pour tout s uu'j'aime les hittoires  demain, j'me rends la dernière tistique
# j'ai pas les miens s'taperont pas comme un prooo, j'ai fait quelques potos de son coeur de la pluie de ma beeger la dernière bague comme un peu de poste  j'laisse pas de raconte ma vibe please dans l'arrre d'homme me dépression d'tout ceux qui prennent les fleurs  les plus douces
# les barres comme le  blagues de ma concurrence et l'aroonne de tous les courses
# ouais, tout ce qu'on veut tout ce qu'on eeste avant d'regarder comme une rathhe
# y'a des schfaris, pas de nous on fait pas l'problème mais j'me repplis l'monde de la mort
# j'ai pas d'bras coup d'son de la drogue, on a marre de brasser le  clips comme un pile éclate la vibe, c'est goûter les contrôlerass de plus belle et mon playan  sur ma tête pour chanter l'jour où j'étais pas belle, j'ai vu les plus trop d'sourires de plus de soleil dans l'balance
# j'ai pas comme un  aasse
# comme un paradeur et des petites lignes sont toutes les coups d'bloques
# c'est les mots dans le  mains baisent les goûts sont les barres de les plus de beuh de son de trou de toi on t'aait les plus grands stores
#
# <REFRAIN>
#
# si c'est les politiques et j'me dois pas faire les autres et j't'ai pas d'pote
# j'ai rien à faire c'est pas trop faiile de la prison please de vengeance
# j'ai caassé, ee monde de caba de faire mais j'me sens mais tu m'as la nuit comme un pager de mes parents, les plans et plus de tabac
# l'homme s'en tape, pour les faibles de la boule mais j'veux pas les plaire
# j'ai pas les balles de toi
#
#  <END>

# %% [markdown]
# # If no restriction on the generation part

# %%
context_gen = "malice"
context_encode = [mapping[i] for i in context_gen]

hid = model.init_hidden(batch_size=1)

encoded = torch.tensor(context_encode, dtype=torch.long).unsqueeze(0)
print("".join([int2char[i] for i in context_encode]), end="")

out, hid = model(encoded, hid)
next_input = encoded[:, -1].unsqueeze(0) 

last_input = 0
first_input = True

while last_input != 70:
    with torch.no_grad():
        out, hid = model(next_input, hid) 

        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)

        if (last_input == 0) and (next_token != list(decod_structure.keys())):
            print(int2char[next_token.item()].upper(), end="")
        elif last_input != 70 : 
            print(int2char[next_token.item()], end="")

        last_input = next_token.item()
        next_input = next_token.view(1, 1)
# Out:
# malice
# Donc tu veux pas me faire mon école
# Toutes les jours
# J'suis dans les meufs m'appellent des pooblèmes de con  mais j'écoute des couplets les blessures s'éteignent la soie de l'argent par la cause de belgique
# On est comme si j'étais comme les couplets sont foutures
# Les sous de mon plus bien de salale  mais on reste aas si si tes potes d'homme pas d'bruit d'la soupe de rêve d'un plug, j'ai bien quand j'mettais pas les battes sont dans l'fond
# J'ai pas b'soin d'causer des fleurs font toutes les couplets d'plus belle la peur d'la musique
# J'ai un poaier sur le  chauds
# J'suis pas là pour les courtes
# J'ai pas d'la seule plume de prod  comme ma maison, j'te dis le  vegresses de la plage est trop là, j'ai mon coup d'contrôle, c'est pas mon aroupe des blessures de la vitesse de mon partinique, t'as des renses, j'me rends l'disciple
# Quelques pattes  j'ai peur de moi comme un pote vie d'un peu de paix
# /γ
# Θ

# %%
matrix = pd.read_csv(r"..\Markov\transition_matrix.csv")

states = np.array(matrix.iloc[6])
prob_transi = np.array(matrix.iloc[0:6])

# %% [markdown]
# # Model loading

# %%
vocab_size = len(int2char)
hidden_size = 250

model = CharRNN(vocab_size, hidden_size, num_layers=3)   

ckpt = torch.load("..\Models\RNN_model.pt", map_location="cpu")
model.load_state_dict(ckpt["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# The char token representing the end of a section is at place 79

# %%
struct = generate_a_song_structure(prob_transi.astype(float),states)

encoded = torch.tensor([mapping[c] for c in struct[1]], dtype=torch.long).unsqueeze(0)
# Out:
# ['<BEGINNING>', '<INTRO>', '<COUPLET>', '<OUTRO>', '<END>']

# %%
hid = model.init_hidden(batch_size=1)

for i in range(len(struct)-2) :

    print()
    print(struct[i+1])
    encoded = torch.tensor([mapping[c] for c in struct[i+1]], dtype=torch.long).unsqueeze(0)

    # prime the model with your encoded context
    out, hid = model(encoded, hid)

    # take the last token of the context
    next_input = encoded[:, -1].unsqueeze(0)  # shape (1, 1)

    last_input = 0
    first_input = True

    while last_input != 79 :
        with torch.no_grad():
            out, hid = model(next_input, hid)   # out shape: (1, 1, vocab_size)

    # sample from logits
        next_token = sample_with_temp_topk(out[0, -1], temperature=0.5, top_k=20)
        last_input = next_token.item()

    # print char
        if first_input and last_input == 79 :
            last_input = 0
            continue

        if next_token.item() != 79 :
            first_input = False
            print(int2char[next_token.item()], end="")


    # prepare next input (still (1, 1))
        next_input = next_token.view(1, 1)

print("\n",struct[-1])
# Out:
# <INTRO>
#
# J'ai trop de rap de part les cames
# Plus de la vie de Port de la main de la cerveau nom du Havre
# Le cours
# J'ai mis le porter le monde sort de passer le bout de la ville de respectif
# Le monde qu'à la pousse de l'homme de barbe de courrer les écoute le lastrune
# La ville dans le mature en mon petite mort se parle de la foule mais un flow de leur fusil d'accusé de La plume de l'argent de la fin du Homme avec le salaire comme les petours de la plume de suiver au contier quand les basses de mal comme des fois qui s'monte dans les masses de la faime du bruit de l'arration
# Comme le mandant des gros cartes de la rue
# Dans la puissance du Havrais de l'espectin de la pression de son habille dans les bouts de la musicule de l'ais de la main de crocation de faire la pertisse de mon sport sont des mosses année du tiers d'un contre une faire les fonds par la plage de l'attertaine
# J'ai fais mieux qu'on en apres de mes plaises mais le garde au fond de ceux qui parle des armes de la rue tout le concert de Panamistes et son son de la Bing
# Bébéra dans le corble
# Aussi le nathone le putain du monde sous les bouches de Dalo
#
# <COUPLET>
#
# Pour les couplets se cours à l'alors
# Le sang de Paname de la gagne de la londe avec les putains en peuple du Panamais sur la meilleur de ces deux ans de poussières
# Sauci de la puis on s'en prends le monde de la panthère
# Monte au lancier
#
# <OUTRO>
#
# J'ai pas le bouche de la rendez le paroles, par les connes comme les mauvaiseux d'un esplise de mon genin de la faute de ressemble de la labeur de l'argent ou de la faute à la couleur artiste de la puritaine
# Le bien quand t'es pas couplet de l'Havre et le poitre
# Les photos pour le coup de la comme de colonienner
# Comme un disque de la profond de la mort de leur partie de la porte des cadames
# J'ai connaître pour les vies et les stantes discillage aux conseils de fond d'un monde sans plus des coups de la rappeur qui en porte les armées du Port de l'attrace de la conseille de l'accère de la paie de Marie sur le tonnaliste
# J'ai la vie qui viennent les emposteurs de ma meuf pas que la raisonne dans le dangereux de l'air, son but de la peau de resens contraire de courrier comme un mariage
# Parle-moi sur le paris de la casser le matin
# J'arrive de la cours
# Le menton du monde sont des pierres de blanc de mes mots
